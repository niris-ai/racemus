# %%
import os
import torch
import random
import natsort
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms
from torchvision.utils import make_grid
from sklearn.model_selection import train_test_split
from sklearn import metrics
from collections import Counter
from PIL import Image

# %%
PATH_TO_FOLDER = "Racemus/racemus_classifier/src"
MODEL_NAME = "resnet50_prova"

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/' + PATH_TO_FOLDER)

# !unzip -o /content/drive/My\ Drive/Racemus/racemus_classifier/data/dataset_training.zip
# !unzip -o /content/drive/My\ Drive/Racemus/racemus_classifier/data/dataset_prediction.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  /content/drive/My Drive/Racemus/racemus_classifier/data/dataset_training.zip
#   inflating: dataset_training/Diseased/0001aa74-bbd7-433b-a900-1dccab39d521___FAM_L.Blight 4508.JPG
#   inflating: dataset_training/Diseased/00090b0f-c140-4e77-8d20-d39f67b75fcc___FAM_B.Rot 0376.JPG
#   inflating: dataset_training/Diseased/0012e1ee-fde3-478f-ab27-18648feb2b05___FAM_L.Blight 1647.JPG
#   inflating: dataset_training/Diseased/002e4d32-15cf-4350-bfba-dde7c8992392___FAM_L.Blight 4740.JPG
#   inflating: dataset_training/Diseased/003d09ef-e16c-4e8a-badf-847d46cb3dc0___FAM_B.Rot 3184.JPG
#   inflating: dataset_training/Diseased/004175d8-dc74-4285-8401-3cc9565730bb___FAM_B.Rot 0626.JPG
#   inflating: dataset_training/Diseased/006efc68-9e46-4168-921c-10ef8065702c___FAM_B.Rot 3470.JPG
#   inflating: dataset_training/Diseased/0075b632-2e34-4e4f-9697-fe2b332b7ef8___FAM_B.Msls 4399.JPG
#   inflating: dataset_training/Diseased/00905d40-bddf-460e-b348-1dbb6a34653b___FAM_B.Rot 0664.JPG
#   inflating: dataset_training/Diseased/0093ee81-2439-414c-bfb5-a5b6cd6aea72___FAM_B.Rot 3429.JPG
#   inflating: dataset_training/Diseased/00a962ad-573b-44b1-97ae-912a6bd6e0b0___FAM_L.Blight 1431.JPG
#   inflating: dataset_training/Diseased/00b65fe8-cee1-4b68-8ef4-1211814f2845___FAM_B.Msls 3990.JPG
#   inflating: dataset_training/Diseased/00c247e8-48d2-4a56-a9f3-4eacfb4d85be___FAM_B.Msls 4197.JPG
#   inflating: dataset_training/Diseased/00cab05d-e87b-4cf6-87d8-284f3ec99626___FAM_B.Rot 3244.JPG
#   inflating: dataset_training/Diseased/00cff577-afd4-4e36-ac9c-a52aa6ae5949___FAM_B.Rot 0508.JPG
#   inflating: dataset_training/Diseased/00ed3cc2-020b-499f-a951-d772dea3b154___FAM_L.Blight 4653.JPG
#   inflating: dataset_training/Diseased/01162551-b800-4df8-ac46-64d17d6ac5bf___FAM_B.Msls 1153.JPG
#   inflating: dataset_training/Diseased/011bb69d-fb9c-4fb9-b8cc-031e91270ec2___FAM_B.Msls 4288.JPG
#   inflating: dataset_training/Diseased/011f307f-e06b-4604-9419-d940f7b00290___FAM_B.Msls 1096.JPG
#   inflating: dataset_training/Diseased/012658ed-f0a3-4791-a996-7115dd1e6e3b___FAM_B.Rot 3036.JPG
#   inflating: dataset_training/Diseased/01445290-a36f-4435-9b7d-bd1a9d1ff79b___FAM_L.Blight 4626.JPG
#   inflating: dataset_training/Diseased/017268b1-c25c-4299-a566-1b7ba3f1591e___FAM_B.Rot 3014.JPG
#   inflating: dataset_training/Diseased/019afd88-6645-44c4-a5d2-bd583b877a50___FAM_B.Msls 1744.JPG
#   inflating: dataset_training/Diseased/019e7c07-16e3-4584-baba-5d38defdfb2a___FAM_L.Blight 4742.JPG
#   inflating: dataset_training/Diseased/01b04553-8472-40ce-9f00-8dff5a1a2777___FAM_L.Blight 4530.JPG
#   inflating: dataset_training/Diseased/01c74b8d-1113-47c0-86a3-6ceea27853c0___FAM_B.Msls 4113.JPG
#   inflating: dataset_training/Diseased/01cdbd4c-bd3e-4277-8e84-60700397daaf___FAM_L.Blight 4755.JPG
#   inflating: dataset_training/Diseased/01d00d79-98e1-46c2-90a9-52dcaeb895d2___FAM_L.Blight 4610.JPG
#   inflating: dataset_training/Diseased/01d4aa8b-cc91-4475-b80c-b5b0ca10f1f6___FAM_B.Rot 3050.JPG
#   inflating: dataset_training/Diseased/02223cc6-30d2-408d-a091-65257d044a50___FAM_B.Msls 0908.JPG
#   inflating: dataset_training/Diseased/0231ac9c-05aa-4710-8753-819c721b29b5___FAM_L.Blight 4639.JPG
#   inflating: dataset_training/Diseased/023df989-ab4c-4f66-a6c8-a41c1142ab7d___FAM_B.Msls 1834.JPG
#   inflating: dataset_training/Diseased/0249d5d6-ca79-40a5-9cdb-3d72382e25e1___FAM_L.Blight 1392.JPG
#   inflating: dataset_training/Diseased/025a9fa7-827a-43c3-a82f-66d9cbfb2055___FAM_B.Msls 4282.JPG
#   inflating: dataset_training/Diseased/02605da9-90bc-4456-ae3f-fa42d0b49c29___FAM_L.Blight 1504.JPG
#   inflating: dataset_training/Diseased/0279ec2c-5470-47e8-b1ba-79442bd323bb___FAM_B.Msls 4396.JPG
#   inflating: dataset_training/Diseased/0285f30b-c22b-483c-be1d-9457bbddc4fa___FAM_L.Blight 1591.JPG
#   inflating: dataset_training/Diseased/02a1df6c-97ec-41d4-b00c-9510741a39dc___FAM_B.Rot 0552.JPG
#   inflating: dataset_training/Diseased/02af0429-46c1-444b-bf62-a4d0198141e8___FAM_B.Msls 1062.JPG
#   inflating: dataset_training/Diseased/02c0e019-97c2-48f5-ac40-90b8789e6288___FAM_B.Rot 0753.JPG
#   inflating: dataset_training/Diseased/02e135dd-a02e-40a5-a049-4b5fa978445c___FAM_B.Rot 3063.JPG
#   inflating: dataset_training/Diseased/02f75392-dbad-4ab8-a35d-d391f9d57113___FAM_B.Rot 3323.JPG
#   inflating: dataset_training/Diseased/0336e894-5963-4a7e-9b56-e802473ae4c5___FAM_B.Msls 1231.JPG
#   inflating: dataset_training/Diseased/03423777-68b9-430e-9787-fbd776740881___FAM_B.Rot 0346.JPG
#   inflating: dataset_training/Diseased/035ed95e-9c14-4096-8dce-21ae0970c6b6___FAM_B.Rot 3175.JPG
#   inflating: dataset_training/Diseased/04f22aa8-7ef0-4cce-8708-394e97a328b1___FAM_B.Rot 3391.JPG
#   inflating: dataset_training/Diseased/04f61deb-4a81-4527-8cb2-f656957595ce___FAM_B.Msls 1218.JPG
#   inflating: dataset_training/Diseased/0560b081-3467-4f76-9c00-895eb436a902___FAM_B.Msls 1733.JPG
#   inflating: dataset_training/Diseased/0563d959-cdc8-4e5f-be50-aff6238218be___FAM_B.Rot 3600.JPG
#   inflating: dataset_training/Diseased/05699682-f68a-4d9e-b773-9f886ca4f374___FAM_L.Blight 1386.JPG
#   inflating: dataset_training/Diseased/058433ea-b746-42b9-9d69-019a17ddf1a3___FAM_B.Rot 3486.JPG
#   inflating: dataset_training/Diseased/0598129d-b448-4576-9c66-650388302622___FAM_B.Msls 4097.JPG
#   inflating: dataset_training/Diseased/05ac9e47-e521-4677-9768-5bcb4e414ce1___FAM_B.Msls 3816.JPG
#   inflating: dataset_training/Diseased/05ca939c-220f-4ad0-a4be-a1de75a99034___FAM_B.Rot 0613.JPG
#   inflating: dataset_training/Diseased/05f01a30-6f7e-4056-bd8a-ecc9998821a9___FAM_L.Blight 4694.JPG
#   inflating: dataset_training/Diseased/05f8c04d-9275-4ceb-99d9-42ba43ca5ec1___FAM_B.Rot 0502.JPG
#   inflating: dataset_training/Diseased/06175772-4b28-4cf5-b973-f4a593772024___FAM_L.Blight 4531.JPG
#   inflating: dataset_training/Diseased/062d27c7-8c0f-4ed9-bd63-e506d9965281___FAM_B.Msls 4200.JPG
#   inflating: dataset_training/Diseased/06316202-5637-41f1-baf7-6d41b9af3cab___FAM_B.Rot 3591.JPG
#   inflating: dataset_training/Diseased/06334f9c-abb5-4ded-b731-3588a818ec85___FAM_B.Rot 3497.JPG
#   inflating: dataset_training/Diseased/06534733-e694-4772-96bb-70bcfc14780e___FAM_B.Msls 4253.JPG
#   inflating: dataset_training/Diseased/066df51b-4f56-417d-8cf0-b6990b27b952___FAM_B.Msls 4382.JPG
#   inflating: dataset_training/Diseased/06710c68-b3c8-4c7b-832c-5bec4aeb8417___FAM_B.Rot 0436.JPG
#   inflating: dataset_training/Diseased/0679fd57-9695-4627-9825-b0a55cdfa84b___FAM_B.Rot 0451.JPG
#   inflating: dataset_training/Diseased/069123c0-8f04-499e-a2ac-687e24b099f4___FAM_B.Msls 3917.JPG
#   inflating: dataset_training/Diseased/06b3cef1-9eeb-4a15-a8c6-429532a64e2e___FAM_B.Msls 4427.JPG
#   inflating: dataset_training/Diseased/06c943c3-7c61-46ec-a6ce-5c8f0536d2b4___FAM_L.Blight 1459.JPG
#   inflating: dataset_training/Diseased/06ca4e74-f852-4ee1-8100-2c88eccdf450___FAM_B.Rot 0585.JPG
#   inflating: dataset_training/Diseased/06d929ae-6cad-452b-b027-7f0d15c221fc___FAM_B.Msls 1817.JPG
#   inflating: dataset_training/Diseased/06eb73c0-225e-447b-ac67-08be159a73b7___FAM_B.Msls 1225.JPG
#   inflating: dataset_training/Diseased/06fde815-e82e-42b1-acb6-c097f126fb9b___FAM_B.Rot 0628.JPG
#   inflating: dataset_training/Diseased/10ac6129-104c-4818-8497-b617119ac54e___FAM_B.Rot 0612.JPG
#   inflating: dataset_training/Diseased/10c068fb-2c3f-4e04-af16-02aed288df24___FAM_B.Msls 1849.JPG
#   inflating: dataset_training/Diseased/10c69f64-73f4-4bb0-9319-b660ffb60e11___FAM_B.Rot 3545.JPG
#   inflating: dataset_training/Diseased/10d4d85d-c98d-4d6f-807f-d6aa5befb259___FAM_B.Msls 4436.JPG
#   inflating: dataset_training/Diseased/10d55a2e-3fa8-4823-bb74-714c5ff225b0___FAM_B.Rot 3001.JPG
#   inflating: dataset_training/Diseased/10eacfba-788f-4c47-9434-2025c25923a8___FAM_L.Blight 4728.JPG
#   inflating: dataset_training/Diseased/10ee05f6-5440-4b66-9979-2a5491d9ebaa___FAM_L.Blight 1644.JPG
#   inflating: dataset_training/Diseased/1116c855-b68e-4b46-a82b-ab5ff7963434___FAM_B.Rot 3569.JPG
#   inflating: dataset_training/Diseased/111b8c34-4f71-4c88-949c-11a8369da8eb___FAM_B.Msls 1297.JPG
#   inflating: dataset_training/Diseased/1132be9e-d2ff-42e6-9cd2-5d4087a39ca8___FAM_B.Rot 0413.JPG
#   inflating: dataset_training/Diseased/114e772d-4784-4d26-b9a6-c15c56ece3ad___FAM_B.Rot 3515.JPG
#   inflating: dataset_training/Diseased/1151f6a1-64a7-4f9b-84d4-39f1a22466bd___FAM_B.Rot 5028.JPG
#   inflating: dataset_training/Diseased/1160c835-3682-4c35-bbc7-f15c212cabda___FAM_B.Msls 1249.JPG
#   inflating: dataset_training/Diseased/116c6549-0f11-4649-b50f-c0555fa88f6b___FAM_B.Msls 4278.JPG
#   inflating: dataset_training/Diseased/119f836d-93b0-4eca-8b86-4c3374072c26___FAM_L.Blight 1672.JPG
#   inflating: dataset_training/Diseased/11b1f91d-8b25-4154-bd9a-f76e4f87c80a___FAM_B.Rot 3254.JPG
#   inflating: dataset_training/Diseased/11b802fc-dde7-4b6b-87a7-cfc80aa450bc___FAM_L.Blight 0812.JPG
#   inflating: dataset_training/Diseased/11d33215-d6b5-4a54-b41f-a6af58187681___FAM_B.Rot 0759.JPG
#   inflating: dataset_training/Diseased/11e6dc21-29f5-40e6-aaec-52b649a404ba___FAM_L.Blight 1449.JPG
#   inflating: dataset_training/Diseased/11ed8598-1b06-498a-ac27-7feda481e0b7___FAM_B.Rot 3593.JPG
#   inflating: dataset_training/Diseased/11f66442-5612-499c-a0a1-77f8c3668234___FAM_B.Rot 0727.JPG
#   inflating: dataset_training/Diseased/1217a708-b472-45b8-9248-ad07de3105d2___FAM_L.Blight 4544.JPG
#   inflating: dataset_training/Diseased/123d0123-f340-4f36-8de4-e9fcaf1a8d17___FAM_B.Msls 0977.JPG
#   inflating: dataset_training/Diseased/12416c11-0fa7-479b-9810-54964096ddcc___FAM_L.Blight 4834.JPG
#   inflating: dataset_training/Diseased/1249a146-35de-4bb5-8291-4ba582cfc3ee___FAM_B.Msls 0825.JPG
#   inflating: dataset_training/Diseased/1a2da798-3f89-4379-90b0-d04951adb782___FAM_L.Blight 3645.JPG
#   inflating: dataset_training/Diseased/1a40fd85-7ac0-4f48-9acc-c12664544683___FAM_B.Msls 1748.JPG
#   inflating: dataset_training/Diseased/1a42bbec-0709-41b6-91d3-0074e1f8e9c7___FAM_B.Msls 3958.JPG
#   inflating: dataset_training/Diseased/1a450cce-95a7-4b1e-a641-95b4d50a1acc___FAM_B.Msls 1747.JPG
#   inflating: dataset_training/Diseased/1a477ab0-0649-48d4-bbbf-fa3600d9ec03___FAM_B.Msls 1347.JPG
#   inflating: dataset_training/Diseased/1a550a2d-aafb-44c7-9358-aa8fceeb183a___FAM_B.Msls 1773.JPG
#   inflating: dataset_training/Diseased/1a56bd56-1e8b-4d61-8469-2df3a74c1c10___FAM_B.Msls 4059.JPG
#   inflating: dataset_training/Diseased/1a603016-c88a-4227-865f-575ddf5eddd2___FAM_B.Rot 0464.JPG
#   inflating: dataset_training/Diseased/1a605788-78ec-4d62-9f87-3ad62309d58f___FAM_B.Msls 4371.JPG
#   inflating: dataset_training/Diseased/1a6aabd0-7ca8-4074-a457-5a8f3662a7d7___FAM_B.Rot 3539.JPG
#   inflating: dataset_training/Diseased/1a860168-80da-45d8-aa29-7b03c04d95de___FAM_B.Msls 1259.JPG
#   inflating: dataset_training/Diseased/1a93f5a0-49ce-4ec1-b47b-13bb1da34a35___FAM_B.Msls 1751.JPG
#   inflating: dataset_training/Diseased/1ab73b8a-ab8f-499b-a38a-ba59c21f8802___FAM_B.Msls 3871.JPG
#   inflating: dataset_training/Diseased/1abf6a06-12f2-4266-97db-01b6291fc71d___FAM_B.Msls 3905.JPG
#   inflating: dataset_training/Diseased/1ac53f1b-5d2c-4f6a-b4fe-dccd5dad551f___FAM_B.Rot 3046.JPG
#   inflating: dataset_training/Diseased/1aeac161-7472-4d64-bd17-da030db1fdcb___FAM_B.Msls 1137.JPG
#   inflating: dataset_training/Diseased/1b1d619f-fc47-4752-90c4-4aceda71b8ec___FAM_L.Blight 3709.JPG
#   inflating: dataset_training/Diseased/1b296ef6-f30d-4bc6-8b90-bf93ff46d623___FAM_L.Blight 1667.JPG
#   inflating: dataset_training/Diseased/1b332769-d8c9-4f5b-b21e-171fcc9f939b___FAM_B.Rot 0640.JPG
#   inflating: dataset_training/Diseased/1b3c8d82-8471-4b90-955e-69a487f135ae___FAM_B.Msls 0835.JPG
#   inflating: dataset_training/Diseased/1b49994b-904a-4f13-8c97-e72b68d9d6e4___FAM_B.Rot 3079.JPG
#   inflating: dataset_training/Diseased/1b5c9aed-b19c-4ce8-953f-c8b4e6474ed5___FAM_B.Rot 5110.JPG
#   inflating: dataset_training/Diseased/1b846a40-3a68-47cc-ae87-cb9a918faed6___FAM_B.Msls 4080.JPG
#   inflating: dataset_training/Diseased/1b89066d-0c1a-4e7a-85de-361639737137___FAM_B.Rot 0657.JPG
#   inflating: dataset_training/Diseased/1b8b4037-44c0-4609-9cff-929955889d37___FAM_B.Msls 1164.JPG
#   inflating: dataset_training/Diseased/1ef3043c-a33f-492e-b873-9eacc52fa9c3___FAM_L.Blight 4594.JPG
#   inflating: dataset_training/Diseased/1f1bdf2c-e908-413f-ac30-9ac372b46764___FAM_L.Blight 4830.JPG
#   inflating: dataset_training/Diseased/1f20a91e-f33c-4e38-937d-ee259477211e___FAM_B.Rot 5016.JPG
#   inflating: dataset_training/Diseased/1f3c15b8-5d36-4238-a6d3-f5a23ad8865c___FAM_B.Rot 3514.JPG
#   inflating: dataset_training/Diseased/1f3e89cb-5cb3-4538-b473-f701eccb6b6c___FAM_L.Blight 3672.JPG
#   inflating: dataset_training/Diseased/1f4911b2-05bb-4784-99cb-cb1170cf96ba___FAM_B.Msls 0938.JPG
#   inflating: dataset_training/Diseased/1f63e823-9232-43bd-8e06-70db7d8bb468___FAM_B.Msls 1166.JPG
#   inflating: dataset_training/Diseased/1f65cd54-490a-49a4-909c-a648ea5bc8ed___FAM_B.Rot 0498.JPG
#   inflating: dataset_training/Diseased/1f772cab-21e1-4458-95fb-6f17e0961d9f___FAM_B.Msls 4141.JPG
#   inflating: dataset_training/Diseased/1f826aa9-11b8-40c5-9206-f70c7138c673___FAM_B.Msls 1737.JPG
#   inflating: dataset_training/Diseased/1f8270ac-8016-457e-8e81-bca5bbcaa784___FAM_B.Msls 1338.JPG
#   inflating: dataset_training/Diseased/1f9c1d18-b444-4f1f-befb-483955c9ff9d___FAM_B.Rot 0572.JPG
#   inflating: dataset_training/Diseased/1f9d01f0-dde4-49f5-9c27-e87432451556___FAM_B.Rot 3414.JPG
#   inflating: dataset_training/Diseased/1fa8564c-87f3-421d-aaf8-bfa276a29ab5___FAM_B.Msls 4166.JPG
#   inflating: dataset_training/Diseased/1fd3808a-4e87-4cc0-8b5a-5e12de26c538___FAM_B.Rot 3253.JPG
#   inflating: dataset_training/Diseased/1fe6c16c-b50b-40ce-92ca-40b92a88696e___FAM_B.Msls 4455.JPG
#   inflating: dataset_training/Diseased/1ff7813b-922e-4ef4-988a-85b3f0c76759___FAM_L.Blight 4891.JPG
#   inflating: dataset_training/Diseased/200b0ce7-899b-4cfe-b36b-1202ad34bc50___FAM_L.Blight 1617.JPG
#   inflating: dataset_training/Diseased/20116670-5108-4cd0-a941-b51046151c43___FAM_B.Rot 3551.JPG
#   inflating: dataset_training/Diseased/2011a0a0-a9f9-4be8-9a2e-db1d4a655d01___FAM_B.Rot 3471.JPG
#   inflating: dataset_training/Diseased/204c54ed-d895-4fb5-a2ba-4164ea1b19d3___FAM_B.Rot 3163.JPG
#   inflating: dataset_training/Diseased/2058103c-82a0-49ef-9b88-68ff282de479___FAM_B.Msls 3909.JPG
#   inflating: dataset_training/Diseased/20665daf-9b0c-4485-84e3-1387941ce4b3___FAM_B.Rot 0516.JPG
#   inflating: dataset_training/Diseased/206a3062-fcf6-4724-a42a-ace810a07afd___FAM_B.Msls 1197.JPG
#   inflating: dataset_training/Diseased/208a1a2c-c037-429c-9476-81fc568bde5f___FAM_B.Rot 3049.JPG
#   inflating: dataset_training/Diseased/20ab9746-0822-4b1b-9785-759d35ffff95___FAM_B.Msls 1829.JPG
#   inflating: dataset_training/Diseased/20b52ff6-9a8b-4bdd-8d52-ff7e820bea22___FAM_B.Msls 3889.JPG
#   inflating: dataset_training/Diseased/20cec8eb-c67c-40fd-a979-57a7eded83d2___FAM_L.Blight 4880.JPG
#   inflating: dataset_training/Diseased/20e25c4b-f2ff-41bc-b8ed-27e04e057db6___FAM_B.Msls 0865.JPG
#   inflating: dataset_training/Diseased/20f4f346-c804-4459-af12-d9e89c35a716___FAM_L.Blight 1426.JPG
#   inflating: dataset_training/Diseased/21008a79-e393-498c-b9f8-7c579b911b3e___FAM_B.Rot 0661.JPG
#   inflating: dataset_training/Diseased/2105463c-cf7a-411f-8254-6618685b4147___FAM_B.Msls 0948.JPG
#   inflating: dataset_training/Diseased/211c977e-d5aa-4a3e-8033-2daf1ba12fb5___FAM_B.Rot 0418.JPG
#   inflating: dataset_training/Diseased/212b261f-2ed6-481e-8dc9-68a4e31772f8___FAM_B.Msls 1239.JPG
#   inflating: dataset_training/Diseased/21325767-874e-4076-b279-6091eb07473c___FAM_B.Msls 4156.JPG
#   inflating: dataset_training/Diseased/21530b5c-f5aa-495f-b567-96a1d25b4388___FAM_B.Rot 0380.JPG
#   inflating: dataset_training/Diseased/215c2541-d7b7-4358-b10d-0eacf448995a___FAM_L.Blight 1646.JPG
#   inflating: dataset_training/Diseased/2160dd5f-c134-440e-b03b-db71a9a9a64a___FAM_B.Msls 4308.JPG
#   inflating: dataset_training/Diseased/217b815b-6f1f-414e-9e05-eb235dbb1efb___FAM_B.Msls 3818.JPG
#   inflating: dataset_training/Diseased/21800966-33fe-49a2-9756-28aa00aec362___FAM_B.Msls 1838.JPG
#   inflating: dataset_training/Diseased/2185c832-4efd-49e0-8848-87f8ad6eca8c___FAM_L.Blight 4503.JPG
#   inflating: dataset_training/Diseased/21ddccfa-2e67-498c-8ae4-e996ce36bdec___FAM_B.Rot 3466.JPG
#   inflating: dataset_training/Diseased/21f6f445-c1f9-487e-ab11-be0801a7422a___FAM_L.Blight 4570.JPG
#   inflating: dataset_training/Diseased/220154d8-a9a0-4705-9626-db37647e138f___FAM_B.Rot 3401.JPG
#   inflating: dataset_training/Diseased/2224007e-bf2b-40a0-976f-738871210fc7___FAM_B.Rot 3587.JPG
#   inflating: dataset_training/Diseased/225fe500-766a-485f-b267-9dcd153b4fc0___FAM_B.Rot 3498.JPG
#   inflating: dataset_training/Diseased/226d7916-5a55-4593-b85f-1e53235b04d2___FAM_B.Rot 3099.JPG
#   inflating: dataset_training/Diseased/2284b3b4-d74e-4fbe-9296-b04e39ae5acb___FAM_B.Msls 0882.JPG
#   inflating: dataset_training/Diseased/228b57e4-cd3f-4b41-a7ff-7d85c9dde7f9___FAM_L.Blight 4869.JPG
#   inflating: dataset_training/Diseased/2290a5b0-8dc5-4b06-813c-a3b3cd20edcb___FAM_B.Msls 1296.JPG
#   inflating: dataset_training/Diseased/22948851-070e-408a-8564-2832b005ef5a___FAM_B.Rot 3520.JPG
#   inflating: dataset_training/Healthy/fa55ec79-9e54-4cb7-a926-658fb7afe4d6___Mt.N.V_HL 9056.JPG
#   inflating: dataset_training/Healthy/fa8cd79e-82e1-4dda-9a82-6ce207f2b557___Mt.N.V_HL 9097.JPG
#   inflating: dataset_training/Healthy/fabd2864-3431-4f44-b3bf-fa3af593fe05___Mt.N.V_HL 9002.JPG
#   inflating: dataset_training/Healthy/fc24bccd-6d46-48b8-9dad-99f7bc0e3eec___Mt.N.V_HL 6031.JPG
#   inflating: dataset_training/Healthy/fce60e82-c31e-4040-ba92-8dde8410e93f___Mt.N.V_HL 8991.JPG
#   inflating: dataset_training/Healthy/fd3c8bea-70d4-4526-8a83-f89c567b65ed___Mt.N.V_HL 6059.JPG
#   inflating: dataset_training/Healthy/fdf4cdd9-cb41-42de-a73e-87301576fade___Mt.N.V_HL 9000.JPG
#   inflating: dataset_training/Healthy/fe54a9e2-461a-457b-a391-f6e3cc99605c___Mt.N.V_HL 9093.JPG
#   inflating: dataset_training/Healthy/feb2cf1a-1903-4fb8-bc99-4b399346fef0___Mt.N.V_HL 6135.JPG
#   inflating: dataset_training/Healthy/fed74aa9-511b-4958-824b-41066b2e5406___Mt.N.V_HL 8918.JPG
#   inflating: dataset_training/Healthy/fefb8922-dcb4-4dbf-8777-237ad9a99c40___Mt.N.V_HL 6085.JPG
#   inflating: dataset_training/Healthy/ff99a93a-ec9b-4a6d-a5e1-1a015cada478___Mt.N.V_HL 9057.JPG
# Archive:  /content/drive/My Drive/Racemus/racemus_classifier/data/dataset_prediction.zip
#   inflating: dataset_prediction/0.png
#   inflating: dataset_prediction/1.PNG
#   inflating: dataset_prediction/10.jpg
#   inflating: dataset_prediction/11.jpg
#   inflating: dataset_prediction/12.jpg
#   inflating: dataset_prediction/2.PNG
#   inflating: dataset_prediction/3.PNG
#   inflating: dataset_prediction/4.PNG
#   inflating: dataset_prediction/5.PNG
#   inflating: dataset_prediction/6.PNG
#   inflating: dataset_prediction/7.PNG
#   inflating: dataset_prediction/8.jpg
#   inflating: dataset_prediction/9.jpg

# %%
# Detects if we have a GPU available
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Name of the directory of the dataset
DATASET = "dataset_training"
# Name of the directory in which to save/load models.
MODELS_DIR = "models"
# Name of the directory in which to save/load statistics files.
STATS_DIR = "stats"
# Name of the directory in which are stored the images to predict.
PRED_DIR = "dataset_prediction"
# Name of the directory in which to save the model predictions.
OUTPUT_DIR = "outputs"



# Number of classes in the dataset
NUM_CLASSES = 2
# Percentage of examples for training
TRAIN_PERC = 0.6
# Percentage of examples for testing
TEST_PERC = 0.5
# Batch size for training (depends on available memory)
BATCH_SIZE = 32
# Number of workers for the dataloaders
NUM_WORKERS = 2
# If True, use a mechanism to handle unbalanced dataset
WEIGHTED = True
# If True, use augmentation on train dataset
AUGMENTED = True
# If True, show some examples of the dataset before the start of training/prediction
SHOW_EXAMPLES = False

# Number of epochs to train for
NUM_EPOCHS = 25
# Indicates the consecutive number of epochs with no improvements over the validation set that are waited before early stopping the training.
# (The saved model is the one before these 3 epochs)
EARLY_STOP = 3
# Random seed for dataset splits
RAND_SEED = 99999

# Momentum
MOMENTUM = 0.9
# Weight decay
WEIGHT_DECAY = 0.00001
# Learning rate
LEARNING_RATE = 0.001

# %%
class ClassificationMetrics:
  def __init__(self, num_classes, device):
    self.C = torch.zeros(num_classes, num_classes)
    self.C = self.C.to(device)

  def add(self, yp, yt):
    with torch.no_grad():
      self.C+=(yt*self.C.shape[1]+yp).bincount(minlength=self.C.numel()).view(self.C.shape).float()

  def clear(self):
    self.C.zero_()

  def acc_sw(self):
    return self.C.diag().sum().item()/self.C.sum()

  def acc_cw(self):
    return (self.C.diag()/(self.C.sum(1))).mean()

  def confusion_matrix(self):
    return self.C

# %%
class ModelResults:
  def __init__(self, model_tag):
    self.model_tag = model_tag
    self.train_acc_sw = []
    self.train_acc_cw = []
    self.val_acc_sw = []
    self.val_acc_cw = []
    self.test_acc_sw = None
    self.test_acc_cw = None
    self.test_precision_score = None
    self.test_recall_score = None
    self.test_f1_score = None
    self.conf_matrix_train = None
    self.conf_matrix_val = None

  def add_acc_sw(self, phase, data):
    if phase == 'train':
      self.train_acc_sw.append(data)
    elif phase == 'val':
      self.val_acc_sw.append(data)
    elif phase == 'test':
      self.test_acc_sw = data

  def add_acc_cw(self, phase, data):
    if phase == 'train':
      self.train_acc_cw.append(data)
    elif phase == 'val':
      self.val_acc_cw.append(data)
    elif phase == 'test':
      self.test_acc_cw = data

  def add_test_scores(self, precision, recall, f1):
    self.test_precision_score = precision
    self.test_recall_score = recall
    self.test_f1_score = f1

  def sava_data_on_csv(self):
    script_dir = os.path.abspath('')
    stats_rel_path = "../data/" + STATS_DIR
    stats_abs_path = os.path.join(script_dir, stats_rel_path)

    dataframe = pd.DataFrame(columns=['EPOCH','TRAIN_ACC_SW','TRAIN_ACC_CW','VAL_ACC_SW','VAL_ACC_CW'])
    for epoch in range(len(self.train_acc_sw)):
      df = pd.DataFrame({'EPOCH': epoch+1, 'TRAIN_ACC_SW': self.train_acc_sw[epoch], 'TRAIN_ACC_CW': self.train_acc_cw[epoch], 'VAL_ACC_SW': self.val_acc_sw[epoch], 'VAL_ACC_CW': self.val_acc_cw[epoch]}, index=[0])
      dataframe = pd.concat([dataframe,df], ignore_index=True, axis=0)
    dataframe.to_csv(stats_abs_path + "/" + self.model_tag + "_train_val_results.csv", index=False)

    dataframe = pd.DataFrame({"TEST_ACC_SW": self.test_acc_sw, "TEST_ACC_CW": self.test_acc_cw, "PRECISION": self.test_precision_score, "RECALL": self.test_recall_score, "F1": self.test_f1_score}, index=[0])
    dataframe.to_csv(stats_abs_path + "/" + self.model_tag + "_test_results.csv", index=False)

# %%
class CustomDataSet(torch.utils.data.Dataset):
  def __init__(self, main_dir, transform):
    self.main_dir = main_dir
    self.transform = transform
    all_imgs = os.listdir(main_dir)
    self.total_imgs = natsort.natsorted(all_imgs)

  def __len__(self):
    return len(self.total_imgs)

  def __getitem__(self, idx):
    img_loc = os.path.join(self.main_dir, self.total_imgs[idx])
    image = Image.open(img_loc).convert("RGB")
    tensor_image = self.transform(image)
    return tensor_image

# %%
def imshow(inp, title=None):
  inp = inp.numpy().transpose((1, 2, 0))
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
  inp = std * inp + mean
  inp = np.clip(inp, 0, 1)
  plt.figure(figsize = (10,10))
  plt.imshow(inp)
  if title is not None:
    plt.title(title)
  plt.pause(0.001)

# %%
def create_dataset_splits(dataset, train_size=0.8, test_size=0.5, weighted=False, augmented=False, batch_size=32, num_workers=2):
  sampler = None

  torch.random.manual_seed(RAND_SEED)
  random.seed(RAND_SEED)

  print('CREATING DATASET SPLITS...')

  data_transforms = {
    'base': 
      transforms.Compose([
        transforms.Resize(256),      
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
      ]),
    'base+aug':
      transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation((-15,15)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
      ])
  }

  dataset_abs_path = dataset

  if augmented:
    dataset_train = datasets.ImageFolder(dataset_abs_path, data_transforms['base+aug'])
  else:
    dataset_train = datasets.ImageFolder(dataset_abs_path, data_transforms['base'])
  dataset_val = datasets.ImageFolder(dataset_abs_path, data_transforms['base'])
  dataset_test = datasets.ImageFolder(dataset_abs_path, data_transforms['base'])

  class_names = dataset_train.classes
  num_classes = len(class_names)
  val_size = (1 - train_size)*test_size

  print('AVAILABLE CLASSES : ' + str(class_names))
  print('SPLITS : train=' + str(train_size) + ' , val=' + str(round(val_size, 3)) + ' , test=' + str(round(1-train_size-val_size, 3)))

  targets = dataset_train.targets

  X_train, X_rem, y_train, y_rem = train_test_split(np.arange(len(targets)),targets, train_size=train_size, stratify=targets, shuffle=True, random_state=RAND_SEED)
  X_valid, X_test, y_valid, y_test = train_test_split(X_rem,y_rem, test_size=test_size, stratify=y_rem, shuffle=True, random_state=RAND_SEED)

  dataset_subsets = {
    'train': torch.utils.data.Subset(dataset_train, X_train),
    'val': torch.utils.data.Subset(dataset_val, X_valid),
    'test': torch.utils.data.Subset(dataset_test, X_test),
  }

  if(weighted):
    print('WEIGHTS: COUNTING LABELS...')

    train_classes = [label for _, label in dataset_subsets['train']]
    class_count = Counter(train_classes)

    print('WEIGHTS: WEIGHTED RANDOM SAMPLER WEIGHTS CALCULATION...')

    weight = [1. / c for c in pd.Series(class_count).sort_index().values]
    samples_weight = np.array([weight[t] for t in train_classes])
    samples_weight = torch.from_numpy(samples_weight)
    samples_weight = samples_weight.double()
    sampler = torch.utils.data.WeightedRandomSampler(samples_weight, len(samples_weight), replacement=True)

  print('GENERATING DATALOADERS...')

  dataloaders = {
    'train': torch.utils.data.DataLoader(dataset_subsets['train'],
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         sampler=sampler),
    'val': torch.utils.data.DataLoader(dataset_subsets['val'],
                                       batch_size=batch_size,
                                       num_workers=num_workers),
    'test': torch.utils.data.DataLoader(dataset_subsets['test'],
                                        batch_size=batch_size,
                                        num_workers=num_workers)
  }

  if SHOW_EXAMPLES:
    inputs, classes = next(iter(dataloaders['train']))
    out = make_grid(inputs)
    imshow(out)
    plt.show()

  print('DATASET SPLITS READY!')

  return dataloaders["train"], dataloaders["val"], dataloaders["test"], class_names, num_classes

# %%
def create_pred_dataloader(img_dir):
  data_transforms = {
    'base': 
      transforms.Compose([
        transforms.Resize((224,224)),      
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
      ])
  }

  dataset_abs_path = img_dir

  dataset_test = CustomDataSet(dataset_abs_path, data_transforms['base'])

  dataloader = torch.utils.data.DataLoader(dataset_test,
                              batch_size=BATCH_SIZE,
                              shuffle=False,
                              num_workers=NUM_WORKERS)

  if SHOW_EXAMPLES:
    inputs = next(iter(dataloader))
    out = make_grid(inputs)
    imshow(out)
    plt.show()

  return dataloader, dataset_test.total_imgs

# %%
def train_one_epoch(model, loss_func, metric_tracker, dataloader, optimizer, epoch, scaler, device):
  model.train()

  metric_tracker.clear()

  for i,(X,yt) in enumerate(dataloader):

    X,yt = X.to(device), yt.to(device)

    optimizer.zero_grad()

    if (DEVICE == 'cuda:0'):
      with torch.cuda.amp.autocast():
        Y = model(X)
        loss = loss_func(Y, yt)
    else:
      Y = model(X)
      loss = loss_func(Y, yt)

    y = Y.argmax(-1).to(device)

    metric_tracker.add(y, yt)

    if (DEVICE == 'cuda:0'):
      scaler.scale(loss).backward()
      scaler.step(optimizer)
      scaler.update()
    else:
      loss.backward()
      optimizer.step()

  return loss

# %%
def validate(model, metric_tracker, dataloader, device):
  model.eval()

  metric_tracker.clear()

  with torch.no_grad(): 
    for i,(X,yt) in enumerate(dataloader):

      X,yt = X.to(device), yt.to(device)

      Y = model(X)
      y = Y.argmax(-1).to(device)

      metric_tracker.add(y,yt)

# %%
def save_model(model_name, model, optimizer, loss, num_epochs, class_names):
  script_dir = os.path.abspath('')
  models_rel_path = "../data/" + MODELS_DIR
  models_abs_path = os.path.join(script_dir, models_rel_path)

  path = models_abs_path + "/model_" + model_name + ".pt"
  torch.save({
            'epoch': num_epochs,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss,
            }, path)

  class_names_df = pd.DataFrame(class_names, columns=["NAME"])
  class_names_df.to_csv(models_abs_path + "/model_" + model_name + "_classes.csv",header=False, index = False)

# %%
def load_model(model_name):
  script_dir = os.path.abspath('')
  models_rel_path = "../data/" + MODELS_DIR
  models_abs_path = os.path.join(script_dir, models_rel_path)

  class_names_df = pd.read_csv(models_abs_path + "/model_" + model_name + "_classes.csv", names=["NAME"])
  class_names = class_names_df.NAME.to_list()
  num_classes = len(class_names)

  checkpoint = torch.load(models_abs_path + "/model_" + model_name + ".pt")
  model = models.resnet50().to(DEVICE)

  for param in model.parameters():
    param.requires_grad = False
  num_ftrs = model.fc.in_features
  model.fc = torch.nn.Linear(num_ftrs, num_classes).to(DEVICE)
  model.load_state_dict(checkpoint['model_state_dict'])
  model.eval()

  class_names_df = pd.read_csv(models_abs_path + "/model_" + model_name + "_classes.csv", names=["NAME"])
  class_names = class_names_df.NAME.to_list()

  return model, class_names

# %%
def train(model, model_name, loss_function, trDataLoader, vlDataLoader, optimizer, lr_scheduler, num_epochs, results, num_classes, class_names, device):

  epochs_no_improve = 0
  epochs_stop = EARLY_STOP
  prev_val = 0

  loss_func = loss_function

  metric_tracker = ClassificationMetrics(num_classes, device)

  scaler = torch.cuda.amp.GradScaler()

  for epoch in range(1,num_epochs+1):

    if epochs_no_improve == epochs_stop:
      print("-- EARLY STOP -------------------------\n")
      break

    print("-- EPOCH {}/{} -------------------------\n".format(epoch, num_epochs))

    epoch_loss = train_one_epoch(model, loss_func, metric_tracker, trDataLoader, optimizer, epoch, scaler, device)

    print("\tTRAIN | acc_sw: {:.4f} | acc_cw: {:.4f}".format(
        metric_tracker.acc_sw(), metric_tracker.acc_cw()
    ))

    results.add_acc_sw("train", metric_tracker.acc_sw().item())
    results.add_acc_cw("train", metric_tracker.acc_cw().item())

    validate(model, metric_tracker, vlDataLoader, device)

    print("\tEVAL  | acc_sw: {:.4f} | acc_cw: {:.4f}\n".format(
        metric_tracker.acc_sw(), metric_tracker.acc_cw()
    ))

    results.add_acc_sw("val", metric_tracker.acc_sw().item())
    results.add_acc_cw("val", metric_tracker.acc_cw().item())

    if metric_tracker.acc_sw().item() <= prev_val:
      epochs_no_improve += 1
    else:
      epochs_no_improve = 0
      prev_val = metric_tracker.acc_sw().item()
      save_model(model_name, model, optimizer, epoch_loss, epoch, class_names)

    lr_scheduler.step()

  return epoch_loss

# %%
def test(model, dataloader, results, num_classes, device):
  metric_tracker = ClassificationMetrics(num_classes, device)

  validate(model,metric_tracker, dataloader, device)

  y_true = []
  y_pred = []

  with torch.no_grad(): 
    for i,(X,yt) in enumerate(dataloader):
      X,yt = X.to(device), yt.to(device)
      Y = model(X)
      y_true.extend(yt.cpu().data.numpy())
      y_pred.extend(Y.argmax(-1).cpu().data.numpy())
  
  precision = metrics.precision_score(y_true,y_pred)
  recall = metrics.recall_score(y_true,y_pred)
  f1 = metrics.f1_score(y_true,y_pred)

  print("\tTEST  | acc_sw: {:.4f} | acc_cw: {:.4f} | prec: {:.4f} | rec: {:.4f} | f1: {:.4f}\n".format(
      metric_tracker.acc_sw(), metric_tracker.acc_cw(), precision, recall, f1
  ))

  results.add_acc_sw("test", metric_tracker.acc_sw().item())
  results.add_acc_cw("test", metric_tracker.acc_cw().item())
  results.add_test_scores(precision, recall, f1)

  return metric_tracker

# %%
def predict(model, model_name, class_names, pred_dir, out_dir):
  dataloader, imgs = create_pred_dataloader(pred_dir)

  y_pred = []

  with torch.no_grad(): 
    for i,X in enumerate(dataloader):
      X = X.to(DEVICE)
      Y = model(X)
      y_pred.extend(Y.argmax(-1).cpu().data.numpy())

  data = []
  counter = 0
  for x in y_pred:
    label = class_names[x]
    data.append([counter, imgs[counter] , label])
    counter += 1

  script_dir = os.path.abspath('')
  out_rel_path = "../data/" + out_dir
  out_abs_path = os.path.join(script_dir, out_rel_path)

  labels_df = pd.DataFrame(data, columns=["#","IMAGE","PREDICTION"])
  labels_df.to_csv(out_abs_path + "/" + model_name + "_output.csv",header=True, index = False)

# %%
def train_model(model_name):

  print("DEVICE : " + str(DEVICE))

  train_dataloader, val_dataloader, test_dataloader, class_names, num_classes = create_dataset_splits(DATASET,
    train_size=TRAIN_PERC, test_size=TEST_PERC, weighted=WEIGHTED, augmented=AUGMENTED, batch_size=BATCH_SIZE, num_workers=NUM_WORKERS)

  results = ModelResults(model_name)

  model = models.resnet50(pretrained=True).to(DEVICE)
  num_ftrs = model.fc.in_features
  model.fc = torch.nn.Linear(num_ftrs, num_classes).to(DEVICE)

  print("MODEL NAME : " + model_name)
  print()
  print(model)
  print()
  
  for param in model.parameters():
    param.requires_grad = True

  optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
  
  lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=LEARNING_RATE/4, max_lr=LEARNING_RATE, mode="exp_range")

  loss_function = torch.nn.CrossEntropyLoss()

  loss = train(model, model_name, loss_function, train_dataloader, val_dataloader, optimizer, lr_scheduler, NUM_EPOCHS, results, num_classes, class_names, DEVICE)
  
  test(model, test_dataloader, results, num_classes, DEVICE)

  results.sava_data_on_csv()

# %%
def get_prediction(model_name):

  model, class_names = load_model(model_name)

  predict(model, model_name, class_names, PRED_DIR, OUTPUT_DIR)

# %%
train_model(MODEL_NAME)
# Out:
# DEVICE : cuda:0
# CREATING DATASET SPLITS...
# AVAILABLE CLASSES : ['Diseased', 'Healthy']
# SPLITS : train=0.6 , val=0.2 , test=0.2
# WEIGHTS: COUNTING LABELS...
# WEIGHTS: WEIGHTED RANDOM SAMPLER WEIGHTS CALCULATION...
# GENERATING DATALOADERS...
# DATASET SPLITS READY!
# MODEL NAME : resnet50_prova
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )
#
# -- EPOCH 1/25 -------------------------
#
# 	TRAIN | acc_sw: 0.8872 | acc_cw: 0.8875
# 	EVAL  | acc_sw: 0.9938 | acc_cw: 0.9913
#
# -- EPOCH 2/25 -------------------------
#
# 	TRAIN | acc_sw: 0.9922 | acc_cw: 0.9923
# 	EVAL  | acc_sw: 0.9975 | acc_cw: 0.9986
#
# -- EPOCH 3/25 -------------------------
#
# 	TRAIN | acc_sw: 0.9963 | acc_cw: 0.9963
# 	EVAL  | acc_sw: 1.0000 | acc_cw: 1.0000
#
# -- EPOCH 4/25 -------------------------
#
# 	TRAIN | acc_sw: 0.9979 | acc_cw: 0.9979
# 	EVAL  | acc_sw: 1.0000 | acc_cw: 1.0000
#
# -- EPOCH 5/25 -------------------------
#
# 	TRAIN | acc_sw: 0.9975 | acc_cw: 0.9976
# 	EVAL  | acc_sw: 1.0000 | acc_cw: 1.0000
#
# -- EPOCH 6/25 -------------------------
#
# 	TRAIN | acc_sw: 0.9963 | acc_cw: 0.9963
# 	EVAL  | acc_sw: 1.0000 | acc_cw: 1.0000
#
# -- EARLY STOP -------------------------
#
# 	TEST  | acc_sw: 0.9988 | acc_cw: 0.9993 | prec: 0.9884 | rec: 1.0000 | f1: 0.9942

# %%
get_prediction(MODEL_NAME)
